# %%
# !pip install youtube-search-python yt-dlp
# !pip install --force-reinstall "httpx<0.28"
# Out:
# Requirement already satisfied: youtube-search-python in c:\users\furla\appdata\local\programs\python\python311\lib\site-packages (1.6.6)
# Requirement already satisfied: yt-dlp in c:\users\furla\appdata\local\programs\python\python311\lib\site-packages (2025.2.19)
# Requirement already satisfied: httpx>=0.14.2 in c:\users\furla\appdata\local\programs\python\python311\lib\site-packages (from youtube-search-python) (0.27.2)
# Requirement already satisfied: anyio in c:\users\furla\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (4.8.0)
# Requirement already satisfied: certifi in c:\users\furla\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\furla\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (1.0.7)
# Requirement already satisfied: idna in c:\users\furla\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (3.10)
# Requirement already satisfied: sniffio in c:\users\furla\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\furla\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.14.2->youtube-search-python) (0.14.0)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\furla\appdata\local\programs\python\python311\lib\site-packages (from anyio->httpx>=0.14.2->youtube-search-python) (4.12.2)
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: C:\Users\furla\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip
# Collecting httpx<0.28
#   Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Collecting anyio (from httpx<0.28)
#   Using cached anyio-4.8.0-py3-none-any.whl (96 kB)
# Collecting certifi (from httpx<0.28)
#   Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Collecting httpcore==1.* (from httpx<0.28)
#   Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Collecting idna (from httpx<0.28)
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting sniffio (from httpx<0.28)
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<0.28)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting typing_extensions>=4.5 (from anyio->httpx<0.28)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing_extensions, sniffio, idna, h11, certifi, httpcore, anyio, httpx
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.1
#     Uninstalling sniffio-1.3.1:
#       Successfully uninstalled sniffio-1.3.1
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.1.31
#     Uninstalling certifi-2025.1.31:
#       Successfully uninstalled certifi-2025.1.31
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.7
#     Uninstalling httpcore-1.0.7:
#       Successfully uninstalled httpcore-1.0.7
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.8.0
#     Uninstalling anyio-4.8.0:
#       Successfully uninstalled anyio-4.8.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.2
#     Uninstalling httpx-0.27.2:
#       Successfully uninstalled httpx-0.27.2
# Successfully installed anyio-4.8.0 certifi-2025.1.31 h11-0.14.0 httpcore-1.0.7 httpx-0.27.2 idna-3.10 sniffio-1.3.1 typing_extensions-4.12.2
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: C:\Users\furla\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import csv
import subprocess
import os
import re
import time
from youtubesearchpython import VideosSearch

# Paths to your input and output CSV files
input_csv = "tracks_features.csv"
output_csv = "new_songs_with_details.csv"

# Folder to store downloaded songs
songs_folder = "songs"
os.makedirs(songs_folder, exist_ok=True)

# Additional columns to add
ADDITIONAL_COLUMNS = ["video_title", "video_url", "file_path"]

# ---------- Utility Functions ----------

def clean_song_data(name, artist):
    """Strip and clean the 'name' and 'artist' fields."""
    clean_name = name.strip()
    clean_artist = artist.strip()
    if clean_artist.startswith("['") and clean_artist.endswith("']"):
        clean_artist = clean_artist[2:-2].strip()
    return clean_name, clean_artist

def sanitize_filename(s):
    """Remove problematic characters and replace spaces with underscores."""
    s = s.strip()
    s = re.sub(r'[^\w\s]', '', s)
    s = s.replace(" ", "_")
    return s

def initialize_output_csv(fieldnames):
    """Write header to the output CSV if it doesn't exist yet."""
    if not os.path.exists(output_csv):
        with open(output_csv, mode="w", newline="", encoding="utf-8") as outfile:
            writer = csv.DictWriter(outfile, fieldnames=fieldnames)
            writer.writeheader()

def get_processed_count():
    """Return how many rows have already been processed (based on output CSV)."""
    if not os.path.exists(output_csv):
        return 0
    with open(output_csv, mode="r", newline="", encoding="utf-8") as infile:
        reader = csv.DictReader(infile)
        return sum(1 for _ in reader)

def append_row_to_csv(row, fieldnames):
    """Immediately append a single row to the output CSV."""
    # Create a new dict that only includes keys in 'fieldnames' (preserving order)
    row_to_write = {col: row.get(col, "") for col in fieldnames}
    try:
        with open(output_csv, mode="a", newline="", encoding="utf-8") as outfile:
            writer = csv.DictWriter(outfile, fieldnames=fieldnames)
            writer.writerow(row_to_write)
    except Exception as write_error:
        print(f"Error writing row to CSV: {write_error}")

def process_row(row, fieldnames):
    """Download and process a single row, returning the updated row with new fields."""
    try:
        # Check for name/artist values
        name_raw = row.get("name", "").strip()
        artist_raw = row.get("artists", "").strip()
        if not name_raw or not artist_raw:
            print("Skipping row due to missing data:", row)
            row["video_title"] = ""
            row["video_url"] = ""
            row["file_path"] = ""
            return row

        # Clean the song name and artist
        name, artist = clean_song_data(name_raw, artist_raw)
        row["name"] = name
        row["artists"] = artist

        # Build the YouTube search query
        query = f"{name} by {artist}"
        print(f"Searching for: {query}")

        # Perform YouTube search with error handling
        try:
            videosSearch = VideosSearch(query, limit=1)
            result = videosSearch.result()
        except Exception as e:
            print(f"Error searching for {query}: {e}")
            row["video_title"] = ""
            row["video_url"] = ""
            row["file_path"] = ""
            return row

        if result.get("result"):
            video_info = result["result"][0]
            video_title = video_info.get("title", "")
            video_url = video_info.get("link", "")
            print(f"Found video: {video_title} - {video_url}")
            row["video_title"] = video_title
            row["video_url"] = video_url

            # Build the output filename (MP3 format)
            safe_song = sanitize_filename(name)
            safe_artist = sanitize_filename(artist)
            output_filename = os.path.join(songs_folder, f"{safe_song}_{safe_artist}.mp3")

            # Download first 30 seconds of audio using yt-dlp
            command = [
                "yt-dlp",
                "--extract-audio",
                "--audio-format", "mp3",
                "--postprocessor-args", "ffmpeg:-ss 0",
                "-o", output_filename,
                video_url
            ]
            print(f"Downloading audio to {output_filename} ...")
            try:
                subprocess.run(command, check=True)
                row["file_path"] = os.path.abspath(output_filename)
            except subprocess.CalledProcessError as e:
                print(f"Error downloading {query}: {e}")
                if os.path.exists(output_filename):
                    print("Audio file exists despite error; updating CSV accordingly.")
                    row["file_path"] = os.path.abspath(output_filename)
                else:
                    row["file_path"] = ""
        else:
            print(f"No results found for {query}")
            row["video_title"] = ""
            row["video_url"] = ""
            row["file_path"] = ""
    except Exception as general_error:
        print(f"Unexpected error processing row {row}: {general_error}")
        row["video_title"] = ""
        row["video_url"] = ""
        row["file_path"] = ""
    return row

# ---------- Main Script ----------

sleep_interval = 5  # Time in seconds to wait before re-checking for new rows

# Set the desired starting row (e.g., 1000 means start processing from the 1000th row)
DESIRED_START_ROW = 100000

# 1) Read the input CSV to get original fieldnames in order and load rows
with open(input_csv, mode="r", newline="", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile)
    original_fieldnames = reader.fieldnames or []  # The original column order from the input CSV
    all_rows = list(reader)

# 2) Create the final fieldnames list by appending new columns to the original order.
fieldnames = list(original_fieldnames)
for col in ADDITIONAL_COLUMNS:
    if col not in fieldnames:
        fieldnames.append(col)

# 3) Initialize the output CSV (write header if it doesn't exist)
initialize_output_csv(fieldnames)

# 4) Determine how many rows have already been processed
processed_count = get_processed_count()
print(f"Already processed {processed_count} rows.")

# 5) If processed_count is less than DESIRED_START_ROW, override it so that processing starts there.
if processed_count < DESIRED_START_ROW:
    print(f"Setting starting row to {DESIRED_START_ROW}.")
    processed_count = DESIRED_START_ROW

print(f"Resuming from row {processed_count + 1} of the input CSV.")

print("Starting infinite processing loop...")
while True:
    try:
        with open(input_csv, mode="r", newline="", encoding="utf-8") as csvfile:
            reader = csv.DictReader(csvfile)
            # Re-read original fieldnames in case the input CSV changes (optional)
            original_fieldnames = reader.fieldnames or []
            all_rows = list(reader)
        total_rows = len(all_rows)
    except Exception as e:
        print(f"Error reading input CSV: {e}")
        total_rows = 0

    if processed_count < total_rows:
        # Process each new row one by one from the processed_count index onward
        for row in all_rows[processed_count:]:
            updated_row = process_row(row, fieldnames)
            append_row_to_csv(updated_row, fieldnames)
            processed_count += 1
    else:
        print(f"No new rows (processed {processed_count} of {total_rows}). Waiting {sleep_interval} seconds...")
        time.sleep(sleep_interval)
# Out:
# Already processed 3120 rows.
# Setting starting row to 100000.
# Resuming from row 100001 of the input CSV.
# Starting infinite processing loop...
# Searching for: Reruns by Holiday Shores
# Found video: Reruns - https://www.youtube.com/watch?v=wC0845Ltzac
# Downloading audio to songs\Reruns_Holiday_Shores.mp3 ...
# Searching for: Phones Don't Feud by Holiday Shores
# Found video: Holiday Shores - Phones Don't Feud (Official Music Video) - https://www.youtube.com/watch?v=gL_rXsAhz-Y
# Downloading audio to songs\Phones_Dont_Feud_Holiday_Shores.mp3 ...
# Searching for: Dens by Holiday Shores
# Found video: Dens - https://www.youtube.com/watch?v=PpFm6xwAtvQ
# Downloading audio to songs\Dens_Holiday_Shores.mp3 ...
# Error downloading Dens by Holiday Shores: Command '['yt-dlp', '--extract-audio', '--audio-format', 'mp3', '--postprocessor-args', 'ffmpeg:-ss 0', '-o', 'songs\\Dens_Holiday_Shores.mp3', 'https://www.youtube.com/watch?v=PpFm6xwAtvQ']' returned non-zero exit status 1.
# Searching for: Errand of Tongue by Holiday Shores
# Found video: Holiday Shores - Errand of Tongue (Yours Truly Session) - https://www.youtube.com/watch?v=epENVMgXsFM
# Downloading audio to songs\Errand_of_Tongue_Holiday_Shores.mp3 ...
# Searching for: Bradley Bear by Holiday Shores
# Found video: Bradley Bear - https://www.youtube.com/watch?v=EIyiKDKxSks
# Downloading audio to songs\Bradley_Bear_Holiday_Shores.mp3 ...
# Searching for: I'll Spend Money I Don't Have by Holiday Shores
# Found video: I'll Spend Money I Don't Have - https://www.youtube.com/watch?v=NE4YXtYAUp4
# Downloading audio to songs\Ill_Spend_Money_I_Dont_Have_Holiday_Shores.mp3 ...
# Searching for: Edge of Our Lives by Holiday Shores
# Found video: Holiday Shores - Edge Of Our Lives (Official Music Video) - https://www.youtube.com/watch?v=UrUbb_utx_o
# Downloading audio to songs\Edge_of_Our_Lives_Holiday_Shores.mp3 ...
# Searching for: Days Drag by Holiday Shores
# Found video: Days Drag - https://www.youtube.com/watch?v=ntVkXVU4MFA
# Downloading audio to songs\Days_Drag_Holiday_Shores.mp3 ...
# Searching for: Experiencer by Holiday Shores
# Found video: Experiencer - https://www.youtube.com/watch?v=T0JPVPcU4o8
# Downloading audio to songs\Experiencer_Holiday_Shores.mp3 ...
# Searching for: Tremor Rolls the Peak by Holiday Shores
# Found video: Tremor Rolls the Peak - https://www.youtube.com/watch?v=cuu49K6vCNY
# Downloading audio to songs\Tremor_Rolls_the_Peak_Holiday_Shores.mp3 ...
# Searching for: The Acrobats by Helvetia
# Found video: The Acrobats - https://www.youtube.com/watch?v=gD3xM-9ZnUk
# Downloading audio to songs\The_Acrobats_Helvetia.mp3 ...
# Searching for: What It Did by Helvetia
# Found video: What It Did - https://www.youtube.com/watch?v=7xq1h4ow7ag
# Downloading audio to songs\What_It_Did_Helvetia.mp3 ...
# Searching for: Honest Gods by Helvetia
# Downloading audio to songs\TV_The_Yohimbe_Brothers.mp3 ...
# Searching for: 30 Spokes by The Yohimbe Brothers
# Found video: 30 Spokes - https://www.youtube.com/watch?v=EJo6URFjXv0
# Downloading audio to songs\30_Spokes_The_Yohimbe_Brothers.mp3 ...
# Searching for: Unimportance by The Yohimbe Brothers
# Found video: Unimportance - https://www.youtube.com/watch?v=qKHmlmxmG8c
# Downloading audio to songs\Unimportance_The_Yohimbe_Brothers.mp3 ...
# Searching for: No Pistolas by The Yohimbe Brothers
# Found video: No Pistolas - https://www.youtube.com/watch?v=uwLVqTuf8xE
# Downloading audio to songs\No_Pistolas_The_Yohimbe_Brothers.mp3 ...
# Searching for: Overcoming by The Yohimbe Brothers
# Found video: Overcoming - https://www.youtube.com/watch?v=dYpCt0VIwhg
# Downloading audio to songs\Overcoming_The_Yohimbe_Brothers.mp3 ...
# Searching for: Words They Use by The Yohimbe Brothers
# Found video: Words They Use - https://www.youtube.com/watch?v=OnjjpZ0hIsc
# Downloading audio to songs\Words_They_Use_The_Yohimbe_Brothers.mp3 ...
# Searching for: Shape 1 by The Yohimbe Brothers
# Found video: Shape 1 - https://www.youtube.com/watch?v=CXfsWDZdVYg
# Downloading audio to songs\Shape_1_The_Yohimbe_Brothers.mp3 ...
# Searching for: Perfect Traveller by The Yohimbe Brothers
# Found video: Perfect Traveller - https://www.youtube.com/watch?v=-70CJZkRGBQ
# Downloading audio to songs\Perfect_Traveller_The_Yohimbe_Brothers.mp3 ...
# Searching for: Underdog by Sly & The Family Stone
# Found video: Sly & The Family Stone - Underdog - https://www.youtube.com/watch?v=HMQQcniF2Bg
# Downloading audio to songs\Underdog_Sly__The_Family_Stone.mp3 ...
# Searching for: If This Room Could Talk by Sly & The Family Stone
# Found video: If This Room Could Talk - https://www.youtube.com/watch?v=2lA9dy-BAnM
# Downloading audio to songs\If_This_Room_Could_Talk_Sly__The_Family_Stone.mp3 ...
# Searching for: Run, Run, Run by Sly & The Family Stone
# Found video: Run, Run, Run - https://www.youtube.com/watch?v=SiLWrU-JX08
# Downloading audio to songs\Run_Run_Run_Sly__The_Family_Stone.mp3 ...
# Searching for: Turn Me Loose by Sly & The Family Stone
# Found video: Turn Me Loose - https://www.youtube.com/watch?v=DpWL60Z5txs
# Downloading audio to songs\Turn_Me_Loose_Sly__The_Family_Stone.mp3 ...
# Searching for: Let Me Hear It From You - Single version, stereo by Sly & The Family Stone
# Found video: Let Me Hear It From You - https://www.youtube.com/watch?v=KsVY87NdXqw
# Downloading audio to songs\Let_Me_Hear_It_From_You__Single_version_stereo_Sly__The_Family_Stone.mp3 ...
# Searching for: Advice by Sly & The Family Stone
# Found video: Advice - https://www.youtube.com/watch?v=5sFOSiSr9l8
# Downloading audio to songs\Advice_Sly__The_Family_Stone.mp3 ...
# Searching for: I Cannot Make It by Sly & The Family Stone
# Found video: I Cannot Make It - https://www.youtube.com/watch?v=UGPsvHd6mbo
# Downloading audio to songs\I_Cannot_Make_It_Sly__The_Family_Stone.mp3 ...
# Downloading audio to songs\Rozil_Fourplay.mp3 ...
# Searching for: Cool Train by Fourplay
# Found video: Cool Train - https://www.youtube.com/watch?v=sRLO-mvkAwo
# Downloading audio to songs\Cool_Train_Fourplay.mp3 ...
# Searching for: Avalabop by Fourplay
# Found video: Avalabop - https://www.youtube.com/watch?v=7aLU2MQNeFM
# Downloading audio to songs\Avalabop_Fourplay.mp3 ...
# Searching for: The Firehouse Chill by Fourplay
# Found video: The Firehouse Chill - https://www.youtube.com/watch?v=UwTKclwHnSY
# Downloading audio to songs\The_Firehouse_Chill_Fourplay.mp3 ...
# Searching for: Departure by Fourplay
# Found video: Departure - https://www.youtube.com/watch?v=b9HTkO5zLqY
# Downloading audio to songs\Departure_Fourplay.mp3 ...
# Searching for: 147 4th St. by Fourplay
# Found video: 147 4th St. - https://www.youtube.com/watch?v=R4jCKHRvWu0
# Downloading audio to songs\147_4th_St_Fourplay.mp3 ...
# Searching for: Springsister by Pia Fraus
# Found video: Springsister - https://www.youtube.com/watch?v=bL7SCiVVdsM
# Downloading audio to songs\Springsister_Pia_Fraus.mp3 ...
# Searching for: Yenissey by Pia Fraus
# Found video: Yenissey - https://www.youtube.com/watch?v=fi8hBzJRIqs
# Downloading audio to songs\Yenissey_Pia_Fraus.mp3 ...
# Searching for: Sailing Yes by Pia Fraus
# Found video: Sailing Yes - https://www.youtube.com/watch?v=SptMoHFNzEc
# Downloading audio to songs\Sailing_Yes_Pia_Fraus.mp3 ...
# Searching for: Doctor Optimism by Pia Fraus
# Found video: Doctor Optimism - https://www.youtube.com/watch?v=eJXMv2yTLAE
# Downloading audio to songs\Doctor_Optimism_Pia_Fraus.mp3 ...
# Searching for: House Eaten by Pia Fraus
# Found video: Pia Fraus - House Eaten - https://www.youtube.com/watch?v=UNrnX-iUesc
# Downloading audio to songs\House_Eaten_Pia_Fraus.mp3 ...
# Searching for: After Summer by Pia Fraus
# Found video: After Summer - https://www.youtube.com/watch?v=rXWCOODJ370
# Downloading audio to songs\After_Summer_Pia_Fraus.mp3 ...
# Searching for: Late Again by Pia Fraus
# Found video: Late Again - https://www.youtube.com/watch?v=K6GelBMos8Y
# Downloading audio to songs\Late_Again_Pia_Fraus.mp3 ...
# Searching for: Mute the Birds by Pia Fraus
# Found video: Mute the Birds - https://www.youtube.com/watch?v=gsZzYypZsw4
# Downloading audio to songs\Mute_the_Birds_Pia_Fraus.mp3 ...
# Searching for: Loveloops by Pia Fraus
# Found video: Loveloops - https://www.youtube.com/watch?v=xNNxndMjVkA
# Downloading audio to songs\Loveloops_Pia_Fraus.mp3 ...
# Searching for: Far Fade Whisper by Pia Fraus
# Found video: Far Fade Whisper - https://www.youtube.com/watch?v=ozjq1Q6UDzc
# Downloading audio to songs\Far_Fade_Whisper_Pia_Fraus.mp3 ...
# Searching for: Wondering by Glengarry Bhoys
# Found video: Wondering - https://www.youtube.com/watch?v=8a0pjTrsMWw
# Downloading audio to songs\Wondering_Glengarry_Bhoys.mp3 ...
# Downloading audio to songs\Summertime_Red_Molly.mp3 ...
# Searching for: Is the Blue Moon Still Shining by Red Molly
# Found video: Is the Blue Moon Still Shining - https://www.youtube.com/watch?v=LYkjBBFoonQ
# Downloading audio to songs\Is_the_Blue_Moon_Still_Shining_Red_Molly.mp3 ...
# Searching for: Honey on My Grave by Red Molly
# Found video: Red Molly - Honey On My Grave - Cooldog Concert Series - https://www.youtube.com/watch?v=BF1ywJtPQ3Q
# Downloading audio to songs\Honey_on_My_Grave_Red_Molly.mp3 ...
# Searching for: Old Dancing Fool by Red Molly
# Found video: Old Dancing Fool - https://www.youtube.com/watch?v=TCuCz72a7B0
# Downloading audio to songs\Old_Dancing_Fool_Red_Molly.mp3 ...
# Searching for: Sentimental Gentleman from Georgia by Red Molly
# Found video: Sentimental Gentleman from Georgia - https://www.youtube.com/watch?v=LJwCka0cSFY
# Downloading audio to songs\Sentimental_Gentleman_from_Georgia_Red_Molly.mp3 ...
# Searching for: Wayfaring Stranger by Red Molly
# Found video: Wayfaring Stranger - https://www.youtube.com/watch?v=vx5f-n3LKpo
# Downloading audio to songs\Wayfaring_Stranger_Red_Molly.mp3 ...
# Searching for: This Farm Needs a Man by Red Molly
# Found video: This Farm Needs a Man - https://www.youtube.com/watch?v=6PI7_CHJhdI
# Downloading audio to songs\This_Farm_Needs_a_Man_Red_Molly.mp3 ...
# Searching for: Make Me Lonely Again by Red Molly
# Found video: Make Me Lonely Again - https://www.youtube.com/watch?v=a9hXzS4RjA0
# Downloading audio to songs\Make_Me_Lonely_Again_Red_Molly.mp3 ...
# Searching for: Keep Your Lamp Trimmed and Burning by Red Molly
# Found video: Keep Your Lamp Trimmed and Burning - https://www.youtube.com/watch?v=Rwy1Rja2TbU
# Downloading audio to songs\Keep_Your_Lamp_Trimmed_and_Burning_Red_Molly.mp3 ...
# Searching for: May I Suggest by Red Molly
# Found video: May I Suggest - https://www.youtube.com/watch?v=WMWk9J_riPw
# Downloading audio to songs\May_I_Suggest_Red_Molly.mp3 ...
# Searching for: Twilight Calling by Gaia Consort
# Found video: Twilight Calling - https://www.youtube.com/watch?v=_4zv2oM3-BY
# Downloading audio to songs\Twilight_Calling_Gaia_Consort.mp3 ...
# Searching for: Only Now by Gaia Consort
# Found video: Only Now - https://www.youtube.com/watch?v=6ACzniPdQn4
# Downloading audio to songs\Only_Now_Gaia_Consort.mp3 ...
# Searching for: Dirty Little Secret by Gaia Consort
# Found video: Dirty Little Secret - https://www.youtube.com/watch?v=ups3CQmdPrg
# Downloading audio to songs\Dirty_Little_Secret_Gaia_Consort.mp3 ...
# Searching for: Oracle by Gaia Consort
# Found video: Oracle - https://www.youtube.com/watch?v=p1ZnO2uD18w
# Downloading audio to songs\Oracle_Gaia_Consort.mp3 ...
# Searching for: All We've Got by Gaia Consort
# Found video: All We've Got - https://www.youtube.com/watch?v=8exsWKfAjzE
# Downloading audio to songs\All_Weve_Got_Gaia_Consort.mp3 ...
# Searching for: Heather In The Mead by Gaia Consort
# Found video: Heather in the Mead - https://www.youtube.com/watch?v=2ExMFgAKrYs
# Downloading audio to songs\Heather_In_The_Mead_Gaia_Consort.mp3 ...
# Searching for: Face In The Clouds by Gaia Consort
# Found video: Face in the Clouds - https://www.youtube.com/watch?v=_b40dwR5O-8
# Downloading audio to songs\Face_In_The_Clouds_Gaia_Consort.mp3 ...
# Searching for: Turtles All The Way Down by Gaia Consort
# Found video: Turtles All the Way Down - https://www.youtube.com/watch?v=nqjqIVPebSc
# Downloading audio to songs\Turtles_All_The_Way_Down_Gaia_Consort.mp3 ...
# Searching for: Vitus Dance by Gaia Consort
# Found video: Vitus Dance - https://www.youtube.com/watch?v=CLnZMNDKERg
# Downloading audio to songs\Vitus_Dance_Gaia_Consort.mp3 ...
# Searching for: Perils Of Poly by Gaia Consort
# Found video: Perils of Poly - https://www.youtube.com/watch?v=UPuccHSUD6w
# Downloading audio to songs\Perils_Of_Poly_Gaia_Consort.mp3 ...
# Searching for: Goodnight by Gaia Consort
# Found video: Goodnight - https://www.youtube.com/watch?v=lL6FKv1AQVc
# Downloading audio to songs\Goodnight_Gaia_Consort.mp3 ...
# Searching for: The Green by Gaia Consort
# Found video: The Green - https://www.youtube.com/watch?v=lFj6zQUfbl0
# Downloading audio to songs\The_Green_Gaia_Consort.mp3 ...
# Searching for: Mercy by Gaia Consort
# Found video: Mercy - https://www.youtube.com/watch?v=3bjv6QMVvNY
# Downloading audio to songs\Mercy_Gaia_Consort.mp3 ...
# Searching for: Dynamite! by Sly & The Family Stone
# Found video: Dynamite! - https://www.youtube.com/watch?v=gxfRj2TO0O4
# Downloading audio to songs\Dynamite_Sly__The_Family_Stone.mp3 ...
# Searching for: Chicken by Sly & The Family Stone
# Found video: Chicken - https://www.youtube.com/watch?v=Gb-8-2D8kdw
# Downloading audio to songs\Chicken_Sly__The_Family_Stone.mp3 ...
# Searching for: Plastic Jim by Sly & The Family Stone
# Found video: Plastic Jim - https://www.youtube.com/watch?v=mFr8w8QPI9E
# Downloading audio to songs\Plastic_Jim_Sly__The_Family_Stone.mp3 ...
# Searching for: Fun by Sly & The Family Stone
# Found video: Fun - https://www.youtube.com/watch?v=yLBZBv-J8w0
# Downloading audio to songs\Fun_Sly__The_Family_Stone.mp3 ...
# Searching for: Into My Own Thing by Sly & The Family Stone
# Found video: Into My Own Thing - https://www.youtube.com/watch?v=9-gt5fRWH6c
# Downloading audio to songs\Into_My_Own_Thing_Sly__The_Family_Stone.mp3 ...
# Searching for: Harmony by Sly & The Family Stone
# Found video: Harmony - https://www.youtube.com/watch?v=SwoSHG4tnlk
# Downloading audio to songs\Harmony_Sly__The_Family_Stone.mp3 ...
# Searching for: Life by Sly & The Family Stone
# Found video: Life - https://www.youtube.com/watch?v=D71VV30MYog
# Downloading audio to songs\Life_Sly__The_Family_Stone.mp3 ...
# Searching for: Love City by Sly & The Family Stone
# Found video: Sly & The Family Stone "Love City" on The Ed Sullivan Show - https://www.youtube.com/watch?v=JcxVSQ_zKAo
# Downloading audio to songs\Love_City_Sly__The_Family_Stone.mp3 ...
# Searching for: I'm an Animal by Sly & The Family Stone
# Found video: I'm an Animal - https://www.youtube.com/watch?v=iCDc711Wd7k
# Downloading audio to songs\Im_an_Animal_Sly__The_Family_Stone.mp3 ...
# Searching for: M'Lady by Sly & The Family Stone
# Found video: M'Lady - https://www.youtube.com/watch?v=6ikqbezPNg8
# Downloading audio to songs\MLady_Sly__The_Family_Stone.mp3 ...
# Searching for: Jane is a Groupee by Sly & The Family Stone
# Found video: Jane is a Groupee - https://www.youtube.com/watch?v=Ee2Nj5YRlOE
# Downloading audio to songs\Jane_is_a_Groupee_Sly__The_Family_Stone.mp3 ...
# Searching for: Dynamite! - Single Version by Sly & The Family Stone
# Found video: Dynamite! - https://www.youtube.com/watch?v=gxfRj2TO0O4
# Downloading audio to songs\Dynamite__Single_Version_Sly__The_Family_Stone.mp3 ...
# Searching for: Seven More Days by Sly & The Family Stone
# Found video: Seven More Days - https://www.youtube.com/watch?v=6jXCXKpAxcs
# Downloading audio to songs\Seven_More_Days_Sly__The_Family_Stone.mp3 ...
# Searching for: Pressure by Sly & The Family Stone
# Found video: Pressure - https://www.youtube.com/watch?v=SMT0efm6MmQ
# Downloading audio to songs\Pressure_Sly__The_Family_Stone.mp3 ...
# Searching for: Sorrow - Instrumental by Sly & The Family Stone
# Found video: Sorrow (Instrumental) - https://www.youtube.com/watch?v=MgzWb841ufA
# Downloading audio to songs\Sorrow__Instrumental_Sly__The_Family_Stone.mp3 ...
# Searching for: Enlighten Our Kind by The Greatness Design
# Found video: Enlighten Our Kind - https://www.youtube.com/watch?v=VNI4HWkQ6wc
# Downloading audio to songs\Enlighten_Our_Kind_The_Greatness_Design.mp3 ...
# Searching for: The Sprawling Empire by The Greatness Design
# Found video: The Sprawling Empire - https://www.youtube.com/watch?v=bxQEayd7TzQ
# Downloading audio to songs\The_Sprawling_Empire_The_Greatness_Design.mp3 ...
# Searching for: A Worldview Arises by The Greatness Design
# Found video: A World View Arises   The Greatness Design - https://www.youtube.com/watch?v=-x3IWWsijyA
# Downloading audio to songs\A_Worldview_Arises_The_Greatness_Design.mp3 ...
# Searching for: Trouble Times by The Greatness Design
# Found video: Trouble Times   The Greatness Design - https://www.youtube.com/watch?v=ejnaCBPW6sQ
# Downloading audio to songs\Trouble_Times_The_Greatness_Design.mp3 ...
# Searching for: Redefine This Course by The Greatness Design
# Found video: The Greatness Design - redefine this course - https://www.youtube.com/watch?v=5gliSaaptao
# Downloading audio to songs\Redefine_This_Course_The_Greatness_Design.mp3 ...
# Searching for: Brightest Point (feat. Adrián Terrazas-González) by The Greatness Design
# Found video: Brightest Point (ft. Adrian Terrazas Gonzalez) by The Greatness Design - https://www.youtube.com/watch?v=7Di0bE0UPf0
# Downloading audio to songs\Brightest_Point_feat_Adrián_TerrazasGonzález_The_Greatness_Design.mp3 ...
# Searching for: Silent Exposure by The Greatness Design
# Found video: Silent Exposure - The Greatness Design - https://www.youtube.com/watch?v=SMz2iq_POfc
# Downloading audio to songs\Silent_Exposure_The_Greatness_Design.mp3 ...
# Searching for: The Grim Agreement by The Greatness Design
# Found video: the greatness design - the grim agreement - https://www.youtube.com/watch?v=gWhG572_MWQ
# Downloading audio to songs\The_Grim_Agreement_The_Greatness_Design.mp3 ...
# Searching for: Decrease Humanity by The Greatness Design
# Found video: Decrease Humanity - https://www.youtube.com/watch?v=17Jq5fAJM5U
# Downloading audio to songs\Decrease_Humanity_The_Greatness_Design.mp3 ...
# Searching for: Restore Our Kingdom by The Greatness Design
# Found video: Restore Our Kingdom - The Greatness Design - https://www.youtube.com/watch?v=CV5JQTnafRw
# Downloading audio to songs\Restore_Our_Kingdom_The_Greatness_Design.mp3 ...
# Searching for: The New Path by The Greatness Design
# Found video: The New Path - https://www.youtube.com/watch?v=zPBCHmzTs7E
# Downloading audio to songs\The_New_Path_The_Greatness_Design.mp3 ...
# Searching for: Upon The Empty Surface by The Greatness Design
# Found video: Upon The Empty Surface - https://www.youtube.com/watch?v=QW8NcE0p8iU
# Downloading audio to songs\Upon_The_Empty_Surface_The_Greatness_Design.mp3 ...
# Searching for: When Your Biggest Nightmare Becomes True (2009) by The Greatness Design
# Found video: When Your Biggest Nightmare Becomes True (2009) - https://www.youtube.com/watch?v=6L-ZkowKYDs
# Downloading audio to songs\When_Your_Biggest_Nightmare_Becomes_True_2009_The_Greatness_Design.mp3 ...
# Searching for: Dark Silence (2008) by The Greatness Design
# Found video: Dark Silence (2008) - https://www.youtube.com/watch?v=m7LkaBF8tI8
# Downloading audio to songs\Dark_Silence_2008_The_Greatness_Design.mp3 ...
# Searching for: Beneath the Lies (2006) by The Greatness Design
# Found video: Beneath the Lies (2006) - https://www.youtube.com/watch?v=xukEu80WXrU
# Downloading audio to songs\Beneath_the_Lies_2006_The_Greatness_Design.mp3 ...
# Searching for: I'm Alive by Glengarry Bhoys
# Found video: I'm Alive - https://www.youtube.com/watch?v=rDIDOMKWI74
# Downloading audio to songs\Im_Alive_Glengarry_Bhoys.mp3 ...
# Searching for: Bonnie Broom by Glengarry Bhoys
# Found video: Bonnie Broom - https://www.youtube.com/watch?v=eLssi9aj40U
# Downloading audio to songs\Bonnie_Broom_Glengarry_Bhoys.mp3 ...
# Searching for: La Villee Canadien Francaise by Glengarry Bhoys
# Found video: La Villee Canadien Francaise - https://www.youtube.com/watch?v=3qiHx2M4x08
# Downloading audio to songs\La_Villee_Canadien_Francaise_Glengarry_Bhoys.mp3 ...
# Searching for: Makenzie Kates Lullaby by Glengarry Bhoys
# Found video: Makenzie Kates Lullaby - https://www.youtube.com/watch?v=K_hhOlhatCk
# Downloading audio to songs\Makenzie_Kates_Lullaby_Glengarry_Bhoys.mp3 ...
# Searching for: Swallow by Glengarry Bhoys
# Found video: Swallow - https://www.youtube.com/watch?v=ejjPI-morbA
# Downloading audio to songs\Swallow_Glengarry_Bhoys.mp3 ...
# Searching for: Gibby Bhoys by Glengarry Bhoys
# Found video: Gibby Bhoys - https://www.youtube.com/watch?v=ig6zw_fm3_w
# Downloading audio to songs\Gibby_Bhoys_Glengarry_Bhoys.mp3 ...
# Searching for: My Friend by Glengarry Bhoys
# Found video: My Friend - https://www.youtube.com/watch?v=ph_GqCqXHQE
# Downloading audio to songs\My_Friend_Glengarry_Bhoys.mp3 ...
# Searching for: Humours of Winter by Glengarry Bhoys
# Found video: Humours of Winter - https://www.youtube.com/watch?v=FcSNRGY0Z8U
# Downloading audio to songs\Humours_of_Winter_Glengarry_Bhoys.mp3 ...
# Searching for: P Stands for Paddy by Glengarry Bhoys
# Found video: P Stands for Paddy - https://www.youtube.com/watch?v=BGWAqzwm26g
# Downloading audio to songs\P_Stands_for_Paddy_Glengarry_Bhoys.mp3 ...
# Searching for: Shell's Contention by Glengarry Bhoys
# Found video: Shell's Contention - https://www.youtube.com/watch?v=18PH6jjVL_s
# Downloading audio to songs\Shells_Contention_Glengarry_Bhoys.mp3 ...
# Searching for: Deep Inside by Glengarry Bhoys
# Found video: Deep Inside - https://www.youtube.com/watch?v=fiyKLAq05V8
# Downloading audio to songs\Deep_Inside_Glengarry_Bhoys.mp3 ...
# Searching for: Shamrosk Shore by Glengarry Bhoys
# Found video: Shamrosk Shore - https://www.youtube.com/watch?v=fBYn-yyz0PQ
# Downloading audio to songs\Shamrosk_Shore_Glengarry_Bhoys.mp3 ...
# Searching for: Metronome by Chimeric
# Found video: Chimeric - Metronome - https://www.youtube.com/watch?v=0S1Fm06P0lI
# Downloading audio to songs\Metronome_Chimeric.mp3 ...
# Searching for: Punks by F.O.O.L
# Found video: F.O.O.L - Punks [Tasty Release] - https://www.youtube.com/watch?v=zaF0grwTK-s
# Downloading audio to songs\Punks_FOOL.mp3 ...
# Searching for: This Time by Favright
# Found video: Favright - This Time [edmSpotlight] - https://www.youtube.com/watch?v=_CsdOVEuIng
# Downloading audio to songs\This_Time_Favright.mp3 ...
# Searching for: The Take Down by Koda', 'Dabin
# Found video: Dabin & Koda - The Take Down - https://www.youtube.com/watch?v=BRygKaJYl5g
# Downloading audio to songs\The_Take_Down_Koda_Dabin.mp3 ...
# Searching for: Bezerk by Locknar
# Found video: Locknar - Bezerk [Free DL] - https://www.youtube.com/watch?v=RprTTupnbDc
# Downloading audio to songs\Bezerk_Locknar.mp3 ...
# Searching for: Play by Alex S.
# Found video: Alex S. - Play - https://www.youtube.com/watch?v=MKwXAW3RuH0
# Downloading audio to songs\Play_Alex_S.mp3 ...
# Searching for: Second Universe by Aviators
# Found video: Aviators - Second Universe - https://www.youtube.com/watch?v=F_9f-Gs2IxU
# Downloading audio to songs\Second_Universe_Aviators.mp3 ...
# Searching for: Diamond Sky (feat. Laura Brehm) by Elliot Berger', 'Laura Brehm
# Found video: Elliot Berger - Diamond Sky (feat. Laura Brehm) - https://www.youtube.com/watch?v=-HVvtRgTKlU
# Downloading audio to songs\Diamond_Sky_feat_Laura_Brehm_Elliot_Berger_Laura_Brehm.mp3 ...
# Searching for: Minecraft by Fonik
# Searching for: Lifepulse by Katie Hope
# Found video: Lifepulse - https://www.youtube.com/watch?v=0s-zs1S_0Co
# Downloading audio to songs\Lifepulse_Katie_Hope.mp3 ...
# Searching for: The Way of Innocence by Katie Hope
# Found video: The Way of Innocence - https://www.youtube.com/watch?v=mzyuyOcbgYs
# Downloading audio to songs\The_Way_of_Innocence_Katie_Hope.mp3 ...
# Searching for: The Mind of Buddha by Katie Hope
# Found video: The Mind of Buddha - https://www.youtube.com/watch?v=FeWJ0tb4s5c
# Downloading audio to songs\The_Mind_of_Buddha_Katie_Hope.mp3 ...
# Searching for: Little Jewel by Katie Hope
# Found video: Little Jewel - https://www.youtube.com/watch?v=QBsh6_ySYlI
# Downloading audio to songs\Little_Jewel_Katie_Hope.mp3 ...
# Searching for: At Nirvana's Door by Katie Hope
# Found video: At Nirvana's Door - https://www.youtube.com/watch?v=fxsU023LYws
# Downloading audio to songs\At_Nirvanas_Door_Katie_Hope.mp3 ...
# Searching for: Walking Through by Kaya Project
# Found video: Walking Through - https://www.youtube.com/watch?v=186A-l0gow8
# Downloading audio to songs\Walking_Through_Kaya_Project.mp3 ...
# Searching for: Slide by Kaya Project
# Found video: Slide - https://www.youtube.com/watch?v=BH7M1ie6N58
# Downloading audio to songs\Slide_Kaya_Project.mp3 ...
# Error downloading Slide by Kaya Project: Command '['yt-dlp', '--extract-audio', '--audio-format', 'mp3', '--postprocessor-args', 'ffmpeg:-ss 0', '-o', 'songs\\Slide_Kaya_Project.mp3', 'https://www.youtube.com/watch?v=BH7M1ie6N58']' returned non-zero exit status 1.
# Searching for: Labess by Kaya Project
# Found video: Labess - https://www.youtube.com/watch?v=Hy2iIIpYDfI
# Downloading audio to songs\Labess_Kaya_Project.mp3 ...
# Searching for: Olelo by Kaya Project
# Found video: Olelo - https://www.youtube.com/watch?v=VV_-xvqQceU
# Downloading audio to songs\Olelo_Kaya_Project.mp3 ...
# Searching for: Twin Soul by Kaya Project
# Found video: Twin Soul - https://www.youtube.com/watch?v=aod3lYxyzwg
# Downloading audio to songs\Twin_Soul_Kaya_Project.mp3 ...
# Searching for: Nightflower (kaya project mix) by Kaya Project
# Found video: Nightflower (Kaya Project Remix) - https://www.youtube.com/watch?v=WHu9ZJensf0
# Downloading audio to songs\Nightflower_kaya_project_mix_Kaya_Project.mp3 ...
# Searching for: Kanzaman Breaks by Kaya Project
# Found video: Kaya Project - Kanzaman Breaks - https://www.youtube.com/watch?v=-gaYk4EbwAQ
# Downloading audio to songs\Kanzaman_Breaks_Kaya_Project.mp3 ...
# Searching for: Tribal Shift by Kaya Project
# Found video: Tribal Shift - https://www.youtube.com/watch?v=dpJebKKZTzs
# Downloading audio to songs\Tribal_Shift_Kaya_Project.mp3 ...
# Searching for: Stone Turns Black by Kaya Project
# Found video: Kaya Project - Stone Turns Black - https://www.youtube.com/watch?v=u4DF78HxGis
# Downloading audio to songs\Stone_Turns_Black_Kaya_Project.mp3 ...
# Searching for: Only The Brave by Kaya Project
# Searching for: Sabaddub by Adham Shaikh
# Found video: Adham Shaikh - Sabaddub - https://www.youtube.com/watch?v=tJNUNyPYGdE
# Downloading audio to songs\Sabaddub_Adham_Shaikh.mp3 ...
# Searching for: Constellation by Adham Shaikh
# Found video: Constellation - https://www.youtube.com/watch?v=mpxwXrulMHQ
# Downloading audio to songs\Constellation_Adham_Shaikh.mp3 ...
# Searching for: Orcadrift Remix by Adham Shaikh
# Found video: Adham Shaikh - Orcadrift Remix - https://www.youtube.com/watch?v=FJp4YnL1UfY
# Downloading audio to songs\Orcadrift_Remix_Adham_Shaikh.mp3 ...
# Searching for: Sabadhi by Adham Shaikh
# Found video: Sabadhi - https://www.youtube.com/watch?v=bMllRd0ZTsc
# Downloading audio to songs\Sabadhi_Adham_Shaikh.mp3 ...
# Searching for: Sufi Spin by Adham Shaikh
# Found video: Sufi Spin - https://www.youtube.com/watch?v=3e5GwCVMc44
# Downloading audio to songs\Sufi_Spin_Adham_Shaikh.mp3 ...
# Searching for: Shiraz by Adham Shaikh
# Found video: Shiraz - https://www.youtube.com/watch?v=LrjIY28urng
# Downloading audio to songs\Shiraz_Adham_Shaikh.mp3 ...
# Searching for: Soul Insurance by Angie Stone
# Found video: Soul Insurance - https://www.youtube.com/watch?v=52csWZoh4G0
# Downloading audio to songs\Soul_Insurance_Angie_Stone.mp3 ...
# Searching for: Brotha by Angie Stone
# Found video: Angie Stone - Brotha (Video) - https://www.youtube.com/watch?v=FkUtYqwlHDM
# Downloading audio to songs\Brotha_Angie_Stone.mp3 ...
# Searching for: Pissed Off by Angie Stone
# Found video: Pissed Off - https://www.youtube.com/watch?v=_fT412AAlLs
# Downloading audio to songs\Pissed_Off_Angie_Stone.mp3 ...
# Searching for: More Than A Woman (feat. Calvin) - Duet w/ Calvin by Angie Stone', 'C-Alvin
# Found video: Angie Stone - No More Rain (In This Cloud) (Official Video) - https://www.youtube.com/watch?v=UgG0Hu_FeiA
# Downloading audio to songs\More_Than_A_Woman_feat_Calvin__Duet_w_Calvin_Angie_Stone_CAlvin.mp3 ...
# Searching for: Snowflakes by Angie Stone
# Found video: Snowflakes - https://www.youtube.com/watch?v=RJEaYCxdtZM
# Downloading audio to songs\Snowflakes_Angie_Stone.mp3 ...
# Searching for: Wish I Didn't Miss You by Angie Stone
# Found video: Angie Stone - Wish I Didn't Miss You - https://www.youtube.com/watch?v=9PWz-NubVpM
# Downloading audio to songs\Wish_I_Didnt_Miss_You_Angie_Stone.mp3 ...
# Searching for: Easier Said Than Done by Angie Stone
# Found video: Easier Said Than Done - https://www.youtube.com/watch?v=qGgzfzh3uoQ
# Downloading audio to songs\Easier_Said_Than_Done_Angie_Stone.mp3 ...
# Searching for: Bottles & Cans by Angie Stone
# Found video: Bottles & Cans - https://www.youtube.com/watch?v=378YDAXmoSY
# Downloading audio to songs\Bottles__Cans_Angie_Stone.mp3 ...
# Searching for: The Ingredients Of Love (feat. Musiq Soulchild) - Duet w/ Musiq Soulchild by Angie Stone', 'Musiq Soulchild
# Found video: The Ingredients Of Love - https://www.youtube.com/watch?v=SQpAPylEIMQ
# Downloading audio to songs\The_Ingredients_Of_Love_feat_Musiq_Soulchild__Duet_w_Musiq_Soulchild_Angie_Stone_Musiq_Soulchild.mp3 ...
# Searching for: What U Dyin' For by Angie Stone
# Found video: What U Dyin' For - https://www.youtube.com/watch?v=p7DHbcrtRrk
# Downloading audio to songs\What_U_Dyin_For_Angie_Stone.mp3 ...
# Searching for: Makings Of You - Interlude by Angie Stone
# Found video: Makings Of You (Interlude) - https://www.youtube.com/watch?v=XO-E39lmvr8
# Downloading audio to songs\Makings_Of_You__Interlude_Angie_Stone.mp3 ...
# Searching for: Mad Issues by Angie Stone
# Found video: Mad Issues - https://www.youtube.com/watch?v=L3G4xcgxzS8
# Downloading audio to songs\Mad_Issues_Angie_Stone.mp3 ...
# Searching for: If It Wasn't by Angie Stone
# Found video: If It Wasn't - https://www.youtube.com/watch?v=K49_7Hrszug
# Downloading audio to songs\If_It_Wasnt_Angie_Stone.mp3 ...
# Searching for: 20 Dollars by Angie Stone
# Found video: 20 Dollars - https://www.youtube.com/watch?v=1sIbGYpFdcA
# Downloading audio to songs\20_Dollars_Angie_Stone.mp3 ...
# Searching for: Life Goes On by Angie Stone
# Found video: Life Goes On - https://www.youtube.com/watch?v=ukWYPv6xSb4
# Downloading audio to songs\Life_Goes_On_Angie_Stone.mp3 ...
# Searching for: The Heat - Outro by Angie Stone
# Found video: The Heat (Outro) - https://www.youtube.com/watch?v=L-MxKyNsmKE
# Downloading audio to songs\The_Heat__Outro_Angie_Stone.mp3 ...
# Searching for: Brotha Part II (feat. Alicia Keys & Eve) - Remix Album Version (and R&B Radio Version) by Angie Stone', 'Alicia Keys', 'Eve', 'Kerry "Krucial" Brothers
# Found video: Brotha Part II - https://www.youtube.com/watch?v=VDxjNG-9AfE
# Downloading audio to songs\Brotha_Part_II_feat_Alicia_Keys__Eve__Remix_Album_Version_and_RB_Radio_Version_Angie_Stone_Alicia_Keys_Eve_Kerry_Krucial_Brothers.mp3 ...
# Searching for: Time Of The Month by Angie Stone
# Found video: Time Of The Month - https://www.youtube.com/watch?v=2urW4PEire0
# Downloading audio to songs\Time_Of_The_Month_Angie_Stone.mp3 ...
# Searching for: Stand Up Tall by Dizzee Rascal
# ...
# Downloading audio to songs\Good_Rockin_Tonight_Elvis_Presley.mp3 ...
# Searching for: I Don't Care If the Sun Don't Shine by Elvis Presley
# Found video: Elvis Presley - I Don't Care If the Sun Don't Shine (Official Audio) - https://www.youtube.com/watch?v=Z946b2oSaQA
# Downloading audio to songs\I_Dont_Care_If_the_Sun_Dont_Shine_Elvis_Presley.mp3 ...
# Searching for: Milkcow Blues Boogie by Elvis Presley
# Found video: Elvis Presley - Milkcow Blues Boogie (Official Audio) - https://www.youtube.com/watch?v=wihXFdJ4pM4
# Downloading audio to songs\Milkcow_Blues_Boogie_Elvis_Presley.mp3 ...
# Searching for: You're a Heartbreaker by Elvis Presley
# Found video: Elvis Presley - You're a Heartbreaker (Official Audio) - https://www.youtube.com/watch?v=cemSscuirmo
# Downloading audio to songs\Youre_a_Heartbreaker_Elvis_Presley.mp3 ...
# Searching for: Baby, Let's Play House by Elvis Presley
# Found video: Elvis Presley - Baby, Let's Play House (Official Audio) - https://www.youtube.com/watch?v=xipoD1O-n9o
# Downloading audio to songs\Baby_Lets_Play_House_Elvis_Presley.mp3 ...
# Searching for: I'm Left, You're Right, She's Gone by Elvis Presley
# Found video: Elvis Presley - I'm Left, You're Right, She's Gone (Official Audio) - https://www.youtube.com/watch?v=QqTvokjTa7k
# Downloading audio to songs\Im_Left_Youre_Right_Shes_Gone_Elvis_Presley.mp3 ...
# Searching for: I Forgot to Remember to Forget by Elvis Presley
# Found video: Elvis Presley - I Forgot To Remember To Forget - https://www.youtube.com/watch?v=zXERHsuIyUQ
# Downloading audio to songs\I_Forgot_to_Remember_to_Forget_Elvis_Presley.mp3 ...
# Searching for: Mystery Train by Elvis Presley
# Found video: Elvis Presley - Mystery Train (Official Audio) - https://www.youtube.com/watch?v=njw2oB8oRTs
# Downloading audio to songs\Mystery_Train_Elvis_Presley.mp3 ...
# Searching for: I Love You Because by Elvis Presley
# Found video: Elvis Presley, Lisa Marie Presley - I Love You Because (Duet) - https://www.youtube.com/watch?v=DPtMecSpegM
# Downloading audio to songs\I_Love_You_Because_Elvis_Presley.mp3 ...
# Searching for: Harbor Lights by Elvis Presley
# Found video: Elvis Presley - Harbor Lights (Official Audio) - https://www.youtube.com/watch?v=Xif6edO8UK4
# Downloading audio to songs\Harbor_Lights_Elvis_Presley.mp3 ...
# Searching for: Blue Moon by Elvis Presley
# Found video: Elvis Presley - Blue Moon - https://www.youtube.com/watch?v=MiY5auB3OWg
# Downloading audio to songs\Blue_Moon_Elvis_Presley.mp3 ...
# Searching for: Tomorrow Night by Elvis Presley
# Found video: Tomorrow Night - https://www.youtube.com/watch?v=4zY2XQbrdC8
# Downloading audio to songs\Tomorrow_Night_Elvis_Presley.mp3 ...
# Searching for: I'll Never Let You Go (Little Darlin') by Elvis Presley
# Found video: Elvis Presley - I'll Never Let You Go (Little Darlin') (Official Audio) - https://www.youtube.com/watch?v=5PhvoU55PQA
# Downloading audio to songs\Ill_Never_Let_You_Go_Little_Darlin_Elvis_Presley.mp3 ...
# Searching for: Just Because by Elvis Presley
# Found video: Elvis Presley - Just Because (Official Audio) - https://www.youtube.com/watch?v=qCyMcvXDXWM
# Downloading audio to songs\Just_Because_Elvis_Presley.mp3 ...
# Searching for: I'm Left, You're Right, She's Gone - Slow Version by Elvis Presley
# Found video: I'm Left, You're Right, She's Gone (Slow Version) - https://www.youtube.com/watch?v=VCyk_KXyJy4
# Downloading audio to songs\Im_Left_Youre_Right_Shes_Gone__Slow_Version_Elvis_Presley.mp3 ...
# Searching for: Trying to Get to You by Elvis Presley
# Found video: Elvis Presley - Trying To Get To You ('68 Comeback Special) - https://www.youtube.com/watch?v=KZ64T6gEdC4
# Downloading audio to songs\Trying_to_Get_to_You_Elvis_Presley.mp3 ...
# Searching for: When It Rains, It Really Pours by Elvis Presley
# Found video: Elvis Presley - When It Rains It Pours (Official Audio) - https://www.youtube.com/watch?v=Baa6mnzJoRQ
# Downloading audio to songs\When_It_Rains_It_Really_Pours_Elvis_Presley.mp3 ...
# Searching for: My Happiness by Elvis Presley
# Found video: Elvis Presley - My Happiness (Official Audio) - https://www.youtube.com/watch?v=nXFp8TiGcYw
# Downloading audio to songs\My_Happiness_Elvis_Presley.mp3 ...
# Searching for: That's When Your Heartaches Begin by Elvis Presley
# Found video: Elvis Presley - That's When Your Heartaches Begin (Official Audio) - https://www.youtube.com/watch?v=-ph1MpyL3uc
# Downloading audio to songs\Thats_When_Your_Heartaches_Begin_Elvis_Presley.mp3 ...
# Searching for: I'll Never Stand In Your Way by Elvis Presley
# Found video: Elvis Presley - I'll Never Stand In Your Way (Official Audio) - https://www.youtube.com/watch?v=9-Wcvkt19Y8
# Downloading audio to songs\Ill_Never_Stand_In_Your_Way_Elvis_Presley.mp3 ...
# Searching for: It Wouldn't Be the Same Without You by Elvis Presley
# Found video: Elvis Presley - It Wouldn't Be the Same Without You (Official Audio) - https://www.youtube.com/watch?v=e0gYwlWaz-I
# Downloading audio to songs\It_Wouldnt_Be_the_Same_Without_You_Elvis_Presley.mp3 ...
# Searching for: I Love You Because - Alternate Take by Elvis Presley
# Found video: I Love You Because (Alternate Take) - https://www.youtube.com/watch?v=1DF5wnr2UY4
# Downloading audio to songs\I_Love_You_Because__Alternate_Take_Elvis_Presley.mp3 ...
# Searching for: That's All Right - Alternate Take by Elvis Presley
# Found video: Elvis Presley - That's All Right (Alternate Cut) ('68 Comeback Special) - https://www.youtube.com/watch?v=fi0BmyRQEhI
# Downloading audio to songs\Thats_All_Right__Alternate_Take_Elvis_Presley.mp3 ...
# Searching for: Blue Moon of Kentucky - Alternate Take by Elvis Presley
# Found video: Blue Moon of Kentucky (Alternate Take) - https://www.youtube.com/watch?v=UICH_7umRd4
# Downloading audio to songs\Blue_Moon_of_Kentucky__Alternate_Take_Elvis_Presley.mp3 ...
# Searching for: Blue Moon - Alt. Take by Elvis Presley
# Found video: Blue Moon (Alt. Take) - https://www.youtube.com/watch?v=m2YM0IoeazE
# Downloading audio to songs\Blue_Moon__Alt_Take_Elvis_Presley.mp3 ...
# Searching for: I'll Never Let You Go (Little Darlin') by Elvis Presley
# Found video: Elvis Presley - I'll Never Let You Go (Little Darlin') (Official Audio) - https://www.youtube.com/watch?v=5PhvoU55PQA
# Downloading audio to songs\Ill_Never_Let_You_Go_Little_Darlin_Elvis_Presley.mp3 ...
# Searching for: I Don't Care If The Sun Don't Shine - Alternate Take by Elvis Presley
# Found video: Elvis Presley - I don´t care if the sun don´t shine (alternate take) - https://www.youtube.com/watch?v=P0qIg3NIEJA
# Downloading audio to songs\I_Dont_Care_If_The_Sun_Dont_Shine__Alternate_Take_Elvis_Presley.mp3 ...
# Searching for: I'm Left, You're Right, She's Gone - Slow Version/Alt. Take by Elvis Presley
# Found video: I'm Left, You're Right, She's Gone (Slow Version/Alt. Take) - https://www.youtube.com/watch?v=1l8JmprGcis
# Downloading audio to songs\Im_Left_Youre_Right_Shes_Gone__Slow_VersionAlt_Take_Elvis_Presley.mp3 ...
# Searching for: Fool, Fool, Fool by Elvis Presley
# Found video: Elvis Presley - Fool, Fool, Fool (Official Audio) - https://www.youtube.com/watch?v=IhKaa1i87QM
# Downloading audio to songs\Fool_Fool_Fool_Elvis_Presley.mp3 ...
# Error downloading Fool, Fool, Fool by Elvis Presley: Command '['yt-dlp', '--extract-audio', '--audio-format', 'mp3', '--postprocessor-args', 'ffmpeg:-ss 0', '-o', 'songs\\Fool_Fool_Fool_Elvis_Presley.mp3', 'https://www.youtube.com/watch?v=IhKaa1i87QM']' returned non-zero exit status 1.
# Searching for: Shake, Rattle & Roll by Elvis Presley
# Found video: Elvis Presley- Shake, Rattle and Roll - https://www.youtube.com/watch?v=EHXB3e6Kljs
# Downloading audio to songs\Shake_Rattle__Roll_Elvis_Presley.mp3 ...
# Searching for: I'm Left, You're Right, She's Gone - Live by Elvis Presley
# Found video: Elvis Presley - I'm Left, You're Right, She's Gone (Official Audio) - https://www.youtube.com/watch?v=QqTvokjTa7k
# Downloading audio to songs\Im_Left_Youre_Right_Shes_Gone__Live_Elvis_Presley.mp3 ...
# Searching for: That's All Right - Live by Elvis Presley
# Found video: Elvis Presley - That's All Right ('68 Comeback Special) - https://www.youtube.com/watch?v=YZe_8u-rGWE
# Downloading audio to songs\Thats_All_Right__Live_Elvis_Presley.mp3 ...
# Searching for: Money Honey - Live by Elvis Presley
# Found video: Elvis Presley - Money Honey - 1956 - https://www.youtube.com/watch?v=WnZWIbv4cjU
# Downloading audio to songs\Money_Honey__Live_Elvis_Presley.mp3 ...
# Searching for: Tweedlee Dee - Live by Elvis Presley
# Found video: Elvis Presley Live-Tweedle Dee (30 April 1955)-Texas - https://www.youtube.com/watch?v=_HoJKSidX8Q
# Downloading audio to songs\Tweedlee_Dee__Live_Elvis_Presley.mp3 ...
# Searching for: I Don't Care If the Sun Don't Shine - Live by Elvis Presley
# Found video: Elvis Presley - I Don't Care If the Sun Don't Shine (Official Audio) - https://www.youtube.com/watch?v=Z946b2oSaQA
# Downloading audio to songs\I_Dont_Care_If_the_Sun_Dont_Shine__Live_Elvis_Presley.mp3 ...
# Searching for: Hearts of Stone - Live by Elvis Presley
# Found video: Elvis Presley Live-Hearts of Stone (5 March 1955)-Hayride - https://www.youtube.com/watch?v=8xX4Y1g95bw
# Downloading audio to songs\Hearts_of_Stone__Live_Elvis_Presley.mp3 ...
# Searching for: Ragnampaiza Version by Channel One
# Found video: Channel One Dubs & Instrumentals 1974 - 79 - https://www.youtube.com/watch?v=CDZLi90I7_A
# Downloading audio to songs\Ragnampaiza_Version_Channel_One.mp3 ...
# Searching for: Jail House Version by Channel One
# Found video: EARTH & STONE -   jailhouse set me free i want to go home - channel one - roots stepper reggae - https://www.youtube.com/watch?v=C-xjtWdiEvQ
# Downloading audio to songs\Jail_House_Version_Channel_One.mp3 ...
# Searching for: Speak Easy by Channel One
# Found video: Channel One Dubs & Instrumentals 1974 - 79 - https://www.youtube.com/watch?v=CDZLi90I7_A
# Downloading audio to songs\Speak_Easy_Channel_One.mp3 ...
# Searching for: Natty A General Version by Channel One
# Found video: Channel One Dubs & Instrumentals 1974 - 79 - https://www.youtube.com/watch?v=CDZLi90I7_A
# Downloading audio to songs\Natty_A_General_Version_Channel_One.mp3 ...
# Searching for: Dance Dis Ya Festival Version by Channel One
# Found video: Freddy McKay - Dance this ya Festival extended mix - Festival Song 1976 discomix records CHANNEL 1 - https://www.youtube.com/watch?v=SMWNbQ_oiBA
# Downloading audio to songs\Dance_Dis_Ya_Festival_Version_Channel_One.mp3 ...
# Searching for: Woman Is Like A Shadow Version by Channel One
# Found video: Channel One Dubs & Instrumentals 1974 - 79. - 1) Woman Is Like A Shadow - - https://www.youtube.com/watch?v=ZLuXZZhb2sM
# Downloading audio to songs\Woman_Is_Like_A_Shadow_Version_Channel_One.mp3 ...
# Searching for: King Of The Minstrels by Channel One
# Found video: The Revolutionaries - King Of The Minstrels - https://www.youtube.com/watch?v=8fusk8AX6XA
# Downloading audio to songs\King_Of_The_Minstrels_Channel_One.mp3 ...
# Searching for: Have Mercy Version by Channel One
# Found video: Channel One Dubs & Instrumentals 1974 - 79. - 1) Woman Is Like A Shadow - - https://www.youtube.com/watch?v=ZLuXZZhb2sM
# Downloading audio to songs\Have_Mercy_Version_Channel_One.mp3 ...
# Searching for: CB 200 Version by Channel One
# Found video: Channel One  1) CB200 version 2) Fire Bun version 3) Rema Skank 12" - https://www.youtube.com/watch?v=62d1XFEjuJM
# Downloading audio to songs\CB_200_Version_Channel_One.mp3 ...
# Searching for: Black Man Version by Channel One
# Found video: What a black man can't have a TV - https://www.youtube.com/watch?v=ZCchs0-NdcA
# Downloading audio to songs\Black_Man_Version_Channel_One.mp3 ...
# Searching for: Rema Skank 12" by Channel One
# Found video: Channel One  1) CB200 version 2) Fire Bun version 3) Rema Skank 12" - https://www.youtube.com/watch?v=62d1XFEjuJM
# Downloading audio to songs\Rema_Skank_12_Channel_One.mp3 ...
# Searching for: Ballistic Affair Version by Channel One
# Found video: Leroy Smart - Ballistic Affair - https://www.youtube.com/watch?v=at1ZRkecLKA
# Downloading audio to songs\Ballistic_Affair_Version_Channel_One.mp3 ...
# Searching for: School Days Version by Channel One
# Found video: Trinity “School Days” Classic roots reggae tune, Hitbound/Channel One, Jamaica 1979 - https://www.youtube.com/watch?v=d5YHfzlGV-4
# Downloading audio to songs\School_Days_Version_Channel_One.mp3 ...
# Searching for: Fire Bun Version by Channel One
# Found video: Channel One  1) CB200 version 2) Fire Bun version 3) Rema Skank 12" - https://www.youtube.com/watch?v=62d1XFEjuJM
# Downloading audio to songs\Fire_Bun_Version_Channel_One.mp3 ...
# Searching for: Counter Attack by Channel One
# Found video: Counter Attack - https://www.youtube.com/watch?v=arzzflHWDeQ
# Downloading audio to songs\Counter_Attack_Channel_One.mp3 ...
# Searching for: Answer Me Question Version by Channel One
# Found video: RANKING TREVOR - Answer mi questions + version (1977 Hit bound) - https://www.youtube.com/watch?v=a81DNy7V2tQ
# Downloading audio to songs\Answer_Me_Question_Version_Channel_One.mp3 ...
# Searching for: I Think She Likes Me by Steve Poltz
# Found video: I Think She Likes Me - Steve Poltz - https://www.youtube.com/watch?v=M_wfZJ6_3Cg
# Downloading audio to songs\I_Think_She_Likes_Me_Steve_Poltz.mp3 ...
# Searching for: Rains by Steve Poltz
# Found video: Rains Steve Poltz - https://www.youtube.com/watch?v=7KIcA_R4XKE
# Downloading audio to songs\Rains_Steve_Poltz.mp3 ...
# Searching for: What Would Ghandi Do? by Steve Poltz
# Found video: Steve Poltz & Friends 2000 12 28 Java Joe's, Ocean Beach, CA - https://www.youtube.com/watch?v=KTx9PkOsMtQ
# Downloading audio to songs\What_Would_Ghandi_Do_Steve_Poltz.mp3 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 189
#     186 if processed_count < total_rows:
#     187     # Process each new row one by one from the processed_count index onward
#     188     for row in all_rows[processed_count:]:
# --> 189         updated_row = process_row(row, fieldnames)
#     190         append_row_to_csv(updated_row, fieldnames)
#     191         processed_count += 1
#
# Cell In[2], line 119, in process_row(row, fieldnames)
#     117 print(f"Downloading audio to {output_filename} ...")
#     118 try:
# --> 119     subprocess.run(command, check=True)
#     120     row["file_path"] = os.path.abspath(output_filename)
#     121 except subprocess.CalledProcessError as e:
#
# File c:\Users\furla\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
# --> 556         stdout, stderr = process.communicate(input, timeout=timeout)
#     557     except TimeoutExpired as exc:
#     558         process.kill()
#
# File c:\Users\furla\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1211, in Popen.communicate(self, input, timeout)
#    1209         stderr = self.stderr.read()
#    1210         self.stderr.close()
# -> 1211     self.wait()
#    1212 else:
#    1213     if timeout is not None:
#
# File c:\Users\furla\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1274, in Popen.wait(self, timeout)
#    1272     endtime = _time() + timeout
#    1273 try:
# -> 1274     return self._wait(timeout=timeout)
#    1275 except KeyboardInterrupt:
#    1276     # https://bugs.python.org/issue25942
#    1277     # The first keyboard interrupt waits briefly for the child to
#    1278     # exit under the common assumption that it also received the ^C
#    1279     # generated SIGINT and will exit rapidly.
#    1280     if timeout is not None:
#
# File c:\Users\furla\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1600, in Popen._wait(self, timeout)
#    1597     timeout_millis = int(timeout * 1000)
#    1598 if self.returncode is None:
#    1599     # API note: Returns immediately if timeout_millis == 0.
# -> 1600     result = _winapi.WaitForSingleObject(self._handle,
#    1601                                          timeout_millis)
#    1602     if result == _winapi.WAIT_TIMEOUT:
#    1603         raise TimeoutExpired(self.args, timeout)
#
# KeyboardInterrupt:
